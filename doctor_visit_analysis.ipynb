# %% [markdown]
# <a href="https://colab.research.google.com/github/GaliRamakrishna/Doctor-visits-analysis/blob/main/doctor_visit_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #data preprocessing
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # read the dataset and display

# %%
df = pd.read_csv(r"C:\Users\RAMAKRISHNA\Downloads\DoctorVisits - DA.csv")

# %%
df
# Out:
#       Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 0              1       1  female  0.19    0.55        1        4       1
# 1              2       1  female  0.19    0.45        1        2       1
# 2              3       1    male  0.19    0.90        3        0       0
# 3              4       1    male  0.19    0.15        1        0       0
# 4              5       1    male  0.19    0.45        2        5       1
# ...          ...     ...     ...   ...     ...      ...      ...     ...
# 5185        5186       0  female  0.22    0.55        0        0       0
# 5186        5187       0    male  0.27    1.30        0        0       1
# 5187        5188       0  female  0.37    0.25        1        0       1
# 5188        5189       0  female  0.52    0.65        0        0       0
# 5189        5190       0    male  0.72    0.25        0        0       0
#
#      private freepoor freerepat nchronic lchronic
# 0        yes       no        no       no       no
# 1        yes       no        no       no       no
# 2         no       no        no       no       no
# 3         no       no        no       no       no
# 4         no       no        no      yes       no
# ...      ...      ...       ...      ...      ...
# 5185      no       no        no       no       no
# 5186      no       no        no       no       no
# 5187      no       no       yes       no       no
# 5188      no       no        no       no       no
# 5189      no       no       yes       no       no
#
# [5190 rows x 13 columns]

# %% [markdown]
# # data cleaning

# %% [markdown]
# # converting values of age and income

# %%
df["age"]=df["age"]*100
df["income"]=df["income"]*10000

# %%
df
# Out:
#       Unnamed: 0  visits  gender   age   income  illness  reduced  health  \
# 0              1       1  female  19.0   5500.0        1        4       1
# 1              2       1  female  19.0   4500.0        1        2       1
# 2              3       1    male  19.0   9000.0        3        0       0
# 3              4       1    male  19.0   1500.0        1        0       0
# 4              5       1    male  19.0   4500.0        2        5       1
# ...          ...     ...     ...   ...      ...      ...      ...     ...
# 5185        5186       0  female  22.0   5500.0        0        0       0
# 5186        5187       0    male  27.0  13000.0        0        0       1
# 5187        5188       0  female  37.0   2500.0        1        0       1
# 5188        5189       0  female  52.0   6500.0        0        0       0
# 5189        5190       0    male  72.0   2500.0        0        0       0
#
#      private freepoor freerepat nchronic lchronic
# 0        yes       no        no       no       no
# 1        yes       no        no       no       no
# 2         no       no        no       no       no
# 3         no       no        no       no       no
# 4         no       no        no      yes       no
# ...      ...      ...       ...      ...      ...
# 5185      no       no        no       no       no
# 5186      no       no        no       no       no
# 5187      no       no       yes       no       no
# 5188      no       no        no       no       no
# 5189      no       no       yes       no       no
#
# [5190 rows x 13 columns]

# %% [markdown]
# # removing zero value in income and visits

# %%
df = df[df['income'] != 0]
df = df[df['visits'] != 0]

# %%
df
# Out:
#       Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 0              1       1  female  19.0  5500.0        1        4       1
# 1              2       1  female  19.0  4500.0        1        2       1
# 2              3       1    male  19.0  9000.0        3        0       0
# 3              4       1    male  19.0  1500.0        1        0       0
# 4              5       1    male  19.0  4500.0        2        5       1
# ...          ...     ...     ...   ...     ...      ...      ...     ...
# 1044        1045       2  female  72.0  2500.0        0        0       0
# 1045        1046       1  female  72.0  2500.0        0        0       0
# 1046        1047       1    male  72.0  2500.0        0        0       1
# 1047        1048       1    male  72.0  2500.0        0        0       2
# 1048        1049       1  female  72.0  2500.0        0        0       2
#
#      private freepoor freerepat nchronic lchronic
# 0        yes       no        no       no       no
# 1        yes       no        no       no       no
# 2         no       no        no       no       no
# 3         no       no        no       no       no
# 4         no       no        no      yes       no
# ...      ...      ...       ...      ...      ...
# 1044      no       no       yes       no       no
# 1045      no       no       yes       no      yes
# 1046      no       no       yes       no       no
# 1047      no       no       yes      yes       no
# 1048      no       no       yes       no       no
#
# [1036 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1036 entries, 0 to 1048
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1036 non-null   int64
#  1   visits      1036 non-null   int64
#  2   gender      1036 non-null   object
#  3   age         1036 non-null   float64
#  4   income      1036 non-null   float64
#  5   illness     1036 non-null   int64
#  6   reduced     1036 non-null   int64
#  7   health      1036 non-null   int64
#  8   private     1036 non-null   object
#  9   freepoor    1036 non-null   object
#  10  freerepat   1036 non-null   object
#  11  nchronic    1036 non-null   object
#  12  lchronic    1036 non-null   object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 113.3+ KB

# %% [markdown]
# # Data visualisation

# %%
#histogram for number of visits
plt.figure(figsize=(8, 6))
plt.hist(df['visits'], bins=20, edgecolor='k')
plt.title('Number of Visits Distribution')
plt.xlabel('Number of Visits')
plt.ylabel('Frequency')
plt.show()

# %%
#pie chart for gender distribution
gender_counts = df['gender'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(gender_counts.values, labels=gender_counts.index, autopct='%1.1f%%', wedgeprops=dict(width=0.6))
plt.title('Gender Distribution')
plt.show()

# %%
#box plot for income distribution
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='income')
plt.title('Income Distribution')
plt.xlabel('Income')
plt.show()

# %%
# KDE for age distribution
plt.figure(figsize=(8, 6))
sns.kdeplot(df['age'], shade=True)
plt.title('Age Distribution (KDE)')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()

# %%
#bar plot for illness distribution by gender
plt.figure(figsize=(6, 6))
sns.countplot(data=df, x='gender', hue='illness')
plt.title('Illness Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
#horizontal bar plot for reduced benefits
plt.figure(figsize=(6, 4))
sns.countplot(data=df, y='reduced')
plt.title('Reduced Benefits Distribution')
plt.xlabel('Count')
plt.ylabel('Reduced Benefits')
plt.show()

# %%
#ECDF for healthscore
plt.figure(figsize=(6, 6))
x = np.sort(df['health'])
y = np.arange(1, len(x) + 1) / len(x)
plt.step(x, y)
plt.title('Empirical CDF of Health Score')
plt.xlabel('Health Score')
plt.ylabel('CDF')
plt.show()

# %%
#box plot for private health care
plt.figure(figsize=(6, 6))
sns.countplot(data=df, x='private')
plt.title('Private Healthcare Distribution')
plt.xlabel('Private Healthcare (Yes/No)')
plt.ylabel('Count')
plt.show()

# %%
#pivot table to get the count of "Yes" and "No" visits for 'freepoor', 'freerepat', 'nchronic', 'lchronic'
pivot_table = df.pivot_table(index=['freepoor', 'freerepat'],
                            columns=['nchronic', 'lchronic'],
                            values='visits',
                            aggfunc='count',
                            fill_value=0)

# Plot the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table, annot=True, fmt='d', cmap='YlGnBu', cbar_kws={'label': 'Count'})
plt.title('Count of "Yes" and "No" Visits for Each Combination of Groups')
plt.xlabel('nchronic, lchronic')
plt.ylabel('freepoor, freerepat')
plt.show()
